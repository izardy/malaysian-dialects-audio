# %%
# browse thru youtube videos and identify the most genuine state dialects
# copy the links
# run the script to download the audio files only (mp3 format which to be save in "download" folder)

import ssl
import os
import ffmpeg

ssl._create_default_https_context = ssl._create_unverified_context


link1="https://youtu.be/_K8Wbd2IHxY"
link2="https://youtu.be/48Jz-_jKVV4"
link3="https://youtu.be/kP_-Fa4nIWw"
link4="https://youtu.be/ZOy07PPKMuo"
link5="https://youtu.be/M2yCEcetLcI"
link6="https://youtu.be/OBY0W4UfE5s"
link7="https://youtu.be/gx_a7E9c3Uw"
link8="https://youtu.be/mPGjcszJOT8"
link9="https://youtu.be/JdIdUHPfaUI"
link10="https://youtu.be/6vKjn59VtWo"

links=[link1,link2,link3,link4,link5,link6,link7,link8,link9,link10]

for link in links:
    os.system("youtube-dl -x --audio-format m4a --no-check-certificate --verbose "+link)
    #os.system("mv *.m4a ./download") #linux
    os.system("move *.m4a ./download")  #window

# %%
#combine all the downloaded youtube m4a files into one mp3 file

from pydub import AudioSegment

from pydub import AudioSegment
import os

combined = AudioSegment.empty()  # Initialize an empty AudioSegment
for audio in os.listdir("./download/"):
    sound = AudioSegment.from_file(f"./download/{audio}", format="m4a")
    combined += sound  # Append each audio file to the combined AudioSegment

combined.export("./download/combined.mp3", format="mp3")
# Out:
# <_io.BufferedRandom name='./download/combined.mp3'>

# %%
os.chdir("C:\\Users\\izard\\Documents\\GitHub\\malaysian-dialects-audio\\penang\\download")

# %%
#os.system("rm ./download/*.m4a") #linux
os.system("del *.m4a") #windows
# Out:
# 1

# %%
# Import the AudioSegment class for processing audio and the 
# split_on_silence function for separating out silent chunks.

from pydub import AudioSegment
from pydub.silence import split_on_silence
import ffmpeg

# Define a function to normalize a chunk to a target amplitude.
def match_target_amplitude(aChunk, target_dBFS):
    ''' Normalize given audio chunk '''
    change_in_dBFS = target_dBFS - aChunk.dBFS
    return aChunk.apply_gain(change_in_dBFS)

#os.chdir("C:\\Users\\izard\\Documents\\GitHub\\malaysian-dialects-audio\\penang\\download")

# Load your audio.
song = AudioSegment.from_mp3("combined.mp3")

# Split track where the silence is 0.5 seconds or more and get chunks using 
# the imported function.
chunks = split_on_silence (
    # Use the loaded audio.
    song, 
    # Specify that a silent chunk must be at least 0.5 seconds or 500 ms long.
    min_silence_len = 500,
    # Consider a chunk silent if it's quieter than -16 dBFS.
    # (You may want to adjust this parameter.)
    silence_thresh = -16
)

os.chdir("C:\\Users\\izard\\Documents\\GitHub\\malaysian-dialects-audio\\penang\\chunks")

# Process each chunk with your parameters
for i, chunk in enumerate(chunks):
    # Create a silence chunk that's 0.5 seconds (or 500 ms) long for padding.
    silence_chunk = AudioSegment.silent(duration=500)

    # Add the padding chunk to beginning and end of the entire chunk.
    audio_chunk = silence_chunk + chunk + silence_chunk

    # Normalize the entire chunk.
    normalized_chunk = match_target_amplitude(audio_chunk, -20.0)

    # Export the audio chunk with new bitrate.
    print("Exporting chunk{0}.mp3.".format(i))
    normalized_chunk.export(
        ".//penang-chunk{0}.mp3".format(i),
        bitrate = "192k",
        format = "mp3"
    )
# Out:
# Exporting chunk0.mp3.
# Exporting chunk1.mp3.
# Exporting chunk2.mp3.
# Exporting chunk3.mp3.
# Exporting chunk4.mp3.
# Exporting chunk5.mp3.
# Exporting chunk6.mp3.
# Exporting chunk7.mp3.
# Exporting chunk8.mp3.
# Exporting chunk9.mp3.
# Exporting chunk10.mp3.
# Exporting chunk11.mp3.
# Exporting chunk12.mp3.
# Exporting chunk13.mp3.
# Exporting chunk14.mp3.
# Exporting chunk15.mp3.
# Exporting chunk16.mp3.
# Exporting chunk17.mp3.
# Exporting chunk18.mp3.
# Exporting chunk19.mp3.
# Exporting chunk20.mp3.
# Exporting chunk21.mp3.
# Exporting chunk22.mp3.
# Exporting chunk23.mp3.
# Exporting chunk24.mp3.
# Exporting chunk25.mp3.
# Exporting chunk26.mp3.
# Exporting chunk27.mp3.
# Exporting chunk28.mp3.
# Exporting chunk29.mp3.
# Exporting chunk30.mp3.
# Exporting chunk31.mp3.
# Exporting chunk32.mp3.
# Exporting chunk33.mp3.
# Exporting chunk34.mp3.
# Exporting chunk35.mp3.
# Exporting chunk36.mp3.
# Exporting chunk37.mp3.
# Exporting chunk38.mp3.
# Exporting chunk39.mp3.
# Exporting chunk40.mp3.
# Exporting chunk41.mp3.
# Exporting chunk42.mp3.
# Exporting chunk43.mp3.
# Exporting chunk44.mp3.
# Exporting chunk45.mp3.
# Exporting chunk46.mp3.
# Exporting chunk47.mp3.
# Exporting chunk48.mp3.
# Exporting chunk49.mp3.
# Exporting chunk50.mp3.
# Exporting chunk51.mp3.
# Exporting chunk52.mp3.
# Exporting chunk53.mp3.
# Exporting chunk54.mp3.
# Exporting chunk55.mp3.
# Exporting chunk56.mp3.
# Exporting chunk57.mp3.
# Exporting chunk58.mp3.
# Exporting chunk59.mp3.
# Exporting chunk60.mp3.
# Exporting chunk61.mp3.
# Exporting chunk62.mp3.
# Exporting chunk63.mp3.
# Exporting chunk64.mp3.
# Exporting chunk65.mp3.
# Exporting chunk66.mp3.
# Exporting chunk67.mp3.
# Exporting chunk68.mp3.
# Exporting chunk69.mp3.
# Exporting chunk70.mp3.
# Exporting chunk71.mp3.
# Exporting chunk72.mp3.
# Exporting chunk73.mp3.
# Exporting chunk74.mp3.
# Exporting chunk75.mp3.
# Exporting chunk76.mp3.
# Exporting chunk77.mp3.
# Exporting chunk78.mp3.
# Exporting chunk79.mp3.
# Exporting chunk80.mp3.
# Exporting chunk81.mp3.
# Exporting chunk82.mp3.
# Exporting chunk83.mp3.
# Exporting chunk84.mp3.
# Exporting chunk85.mp3.
# Exporting chunk86.mp3.
# Exporting chunk87.mp3.
# Exporting chunk88.mp3.
# Exporting chunk89.mp3.
# Exporting chunk90.mp3.
# Exporting chunk91.mp3.
# Exporting chunk92.mp3.
# Exporting chunk93.mp3.
# Exporting chunk94.mp3.
# Exporting chunk95.mp3.
# Exporting chunk96.mp3.
# Exporting chunk97.mp3.
# Exporting chunk98.mp3.
# Exporting chunk99.mp3.
# Exporting chunk100.mp3.
# Exporting chunk101.mp3.
# Exporting chunk102.mp3.
# Exporting chunk103.mp3.
# Exporting chunk104.mp3.
# Exporting chunk105.mp3.
# Exporting chunk106.mp3.
# Exporting chunk107.mp3.
# Exporting chunk108.mp3.
# Exporting chunk109.mp3.
# Exporting chunk110.mp3.
# Exporting chunk111.mp3.
# Exporting chunk112.mp3.
# Exporting chunk113.mp3.
# Exporting chunk114.mp3.
# Exporting chunk115.mp3.
# Exporting chunk116.mp3.
# Exporting chunk117.mp3.
# Exporting chunk118.mp3.
# Exporting chunk119.mp3.
# Exporting chunk120.mp3.
# Exporting chunk121.mp3.
# Exporting chunk122.mp3.
# Exporting chunk123.mp3.
# Exporting chunk124.mp3.
# Exporting chunk125.mp3.
# Exporting chunk126.mp3.
# Exporting chunk127.mp3.
# Exporting chunk128.mp3.
# Exporting chunk129.mp3.
# Exporting chunk130.mp3.
# Exporting chunk131.mp3.
# Exporting chunk132.mp3.
# Exporting chunk133.mp3.
# Exporting chunk134.mp3.
# Exporting chunk135.mp3.
# Exporting chunk136.mp3.
# Exporting chunk137.mp3.
# Exporting chunk138.mp3.
# Exporting chunk139.mp3.
# Exporting chunk140.mp3.
# Exporting chunk141.mp3.
# Exporting chunk142.mp3.
# Exporting chunk143.mp3.
# Exporting chunk144.mp3.
# Exporting chunk145.mp3.
# Exporting chunk146.mp3.
# Exporting chunk147.mp3.
# Exporting chunk148.mp3.
# Exporting chunk149.mp3.
# Exporting chunk150.mp3.
# Exporting chunk151.mp3.
# Exporting chunk152.mp3.
# Exporting chunk153.mp3.
# Exporting chunk154.mp3.
# Exporting chunk155.mp3.
# Exporting chunk156.mp3.
# Exporting chunk157.mp3.
# Exporting chunk158.mp3.
# Exporting chunk159.mp3.
# Exporting chunk160.mp3.
# Exporting chunk161.mp3.
# Exporting chunk162.mp3.
# Exporting chunk163.mp3.
# Exporting chunk164.mp3.
# Exporting chunk165.mp3.
# Exporting chunk166.mp3.
# Exporting chunk167.mp3.
# Exporting chunk168.mp3.
# Exporting chunk169.mp3.
# Exporting chunk170.mp3.
# Exporting chunk171.mp3.
# Exporting chunk172.mp3.
# Exporting chunk173.mp3.
# Exporting chunk174.mp3.
# Exporting chunk175.mp3.
# Exporting chunk176.mp3.
# Exporting chunk177.mp3.
# Exporting chunk178.mp3.
# Exporting chunk179.mp3.
# Exporting chunk180.mp3.
# Exporting chunk181.mp3.
# Exporting chunk182.mp3.
# Exporting chunk183.mp3.
# Exporting chunk184.mp3.
# Exporting chunk185.mp3.
# Exporting chunk186.mp3.
# Exporting chunk187.mp3.
# Exporting chunk188.mp3.
# Exporting chunk189.mp3.
# Exporting chunk190.mp3.
# Exporting chunk191.mp3.
# Exporting chunk192.mp3.
# Exporting chunk193.mp3.
# Exporting chunk194.mp3.
# Exporting chunk195.mp3.
# Exporting chunk196.mp3.
# Exporting chunk197.mp3.
# Exporting chunk198.mp3.
# Exporting chunk199.mp3.
# Exporting chunk200.mp3.
# Exporting chunk201.mp3.
# Exporting chunk202.mp3.
# Exporting chunk203.mp3.
# Exporting chunk204.mp3.
# Exporting chunk205.mp3.
# Exporting chunk206.mp3.
# Exporting chunk207.mp3.
# Exporting chunk208.mp3.
# Exporting chunk209.mp3.
# Exporting chunk210.mp3.
# Exporting chunk211.mp3.
# Exporting chunk212.mp3.
# Exporting chunk213.mp3.
# Exporting chunk214.mp3.
# Exporting chunk215.mp3.
# Exporting chunk216.mp3.
# Exporting chunk217.mp3.
# Exporting chunk218.mp3.
# Exporting chunk219.mp3.
# Exporting chunk220.mp3.
# Exporting chunk221.mp3.
# Exporting chunk222.mp3.
# Exporting chunk223.mp3.
# Exporting chunk224.mp3.
# Exporting chunk225.mp3.
# Exporting chunk226.mp3.
# Exporting chunk227.mp3.
# Exporting chunk228.mp3.
# Exporting chunk229.mp3.
# Exporting chunk230.mp3.
# Exporting chunk231.mp3.
# Exporting chunk232.mp3.
# Exporting chunk233.mp3.
# Exporting chunk234.mp3.
# Exporting chunk235.mp3.
# Exporting chunk236.mp3.
# Exporting chunk237.mp3.
# Exporting chunk238.mp3.
# Exporting chunk239.mp3.
# Exporting chunk240.mp3.
# Exporting chunk241.mp3.
# Exporting chunk242.mp3.
# Exporting chunk243.mp3.
# Exporting chunk244.mp3.
# Exporting chunk245.mp3.
# Exporting chunk246.mp3.
# Exporting chunk247.mp3.
# Exporting chunk248.mp3.
# Exporting chunk249.mp3.
# Exporting chunk250.mp3.
# Exporting chunk251.mp3.
# Exporting chunk252.mp3.
# Exporting chunk253.mp3.
# Exporting chunk254.mp3.
# Exporting chunk255.mp3.
# Exporting chunk256.mp3.
# Exporting chunk257.mp3.
# Exporting chunk258.mp3.
# Exporting chunk259.mp3.
# Exporting chunk260.mp3.
# Exporting chunk261.mp3.
# Exporting chunk262.mp3.
# Exporting chunk263.mp3.
# Exporting chunk264.mp3.
# Exporting chunk265.mp3.
# Exporting chunk266.mp3.
# Exporting chunk267.mp3.
# Exporting chunk268.mp3.
# Exporting chunk269.mp3.
# Exporting chunk270.mp3.
# Exporting chunk271.mp3.
# Exporting chunk272.mp3.
# Exporting chunk273.mp3.
# Exporting chunk274.mp3.
# Exporting chunk275.mp3.
# Exporting chunk276.mp3.
# Exporting chunk277.mp3.
# Exporting chunk278.mp3.
# Exporting chunk279.mp3.
# Exporting chunk280.mp3.
# Exporting chunk281.mp3.
# Exporting chunk282.mp3.
# Exporting chunk283.mp3.
# Exporting chunk284.mp3.
# Exporting chunk285.mp3.
# Exporting chunk286.mp3.
# Exporting chunk287.mp3.
# Exporting chunk288.mp3.
# Exporting chunk289.mp3.
# Exporting chunk290.mp3.
# Exporting chunk291.mp3.
# Exporting chunk292.mp3.
# Exporting chunk293.mp3.
# Exporting chunk294.mp3.
# Exporting chunk295.mp3.
# Exporting chunk296.mp3.
# Exporting chunk297.mp3.
# Exporting chunk298.mp3.
# Exporting chunk299.mp3.
# Exporting chunk300.mp3.
# Exporting chunk301.mp3.
# Exporting chunk302.mp3.
# Exporting chunk303.mp3.
# Exporting chunk304.mp3.
# Exporting chunk305.mp3.
# Exporting chunk306.mp3.
# Exporting chunk307.mp3.
# Exporting chunk308.mp3.
# Exporting chunk309.mp3.
# Exporting chunk310.mp3.
# Exporting chunk311.mp3.
# Exporting chunk312.mp3.
# Exporting chunk313.mp3.
# Exporting chunk314.mp3.
# Exporting chunk315.mp3.
# Exporting chunk316.mp3.
# Exporting chunk317.mp3.
# Exporting chunk318.mp3.
# Exporting chunk319.mp3.
# Exporting chunk320.mp3.
# Exporting chunk321.mp3.
# Exporting chunk322.mp3.
# Exporting chunk323.mp3.
# Exporting chunk324.mp3.
# Exporting chunk325.mp3.
# Exporting chunk326.mp3.
# Exporting chunk327.mp3.
# Exporting chunk328.mp3.
# Exporting chunk329.mp3.
# Exporting chunk330.mp3.
# Exporting chunk331.mp3.
# Exporting chunk332.mp3.
# Exporting chunk333.mp3.
# Exporting chunk334.mp3.
# Exporting chunk335.mp3.
# Exporting chunk336.mp3.
# Exporting chunk337.mp3.
# Exporting chunk338.mp3.
# Exporting chunk339.mp3.
# Exporting chunk340.mp3.
# Exporting chunk341.mp3.
# Exporting chunk342.mp3.
# Exporting chunk343.mp3.
# Exporting chunk344.mp3.
# Exporting chunk345.mp3.
# Exporting chunk346.mp3.
# Exporting chunk347.mp3.
# Exporting chunk348.mp3.
# Exporting chunk349.mp3.
# Exporting chunk350.mp3.
# Exporting chunk351.mp3.
# Exporting chunk352.mp3.
# Exporting chunk353.mp3.
# Exporting chunk354.mp3.
# Exporting chunk355.mp3.
# Exporting chunk356.mp3.
# Exporting chunk357.mp3.
# Exporting chunk358.mp3.
# Exporting chunk359.mp3.
# Exporting chunk360.mp3.
# Exporting chunk361.mp3.
# Exporting chunk362.mp3.
# Exporting chunk363.mp3.
# Exporting chunk364.mp3.
# Exporting chunk365.mp3.
# Exporting chunk366.mp3.
# Exporting chunk367.mp3.
# Exporting chunk368.mp3.
# Exporting chunk369.mp3.
# Exporting chunk370.mp3.
# Exporting chunk371.mp3.
# Exporting chunk372.mp3.
# Exporting chunk373.mp3.
# Exporting chunk374.mp3.
# Exporting chunk375.mp3.
# Exporting chunk376.mp3.
# Exporting chunk377.mp3.
# Exporting chunk378.mp3.
# Exporting chunk379.mp3.
# Exporting chunk380.mp3.
# Exporting chunk381.mp3.
# Exporting chunk382.mp3.
# Exporting chunk383.mp3.
# Exporting chunk384.mp3.
# Exporting chunk385.mp3.
# Exporting chunk386.mp3.
# Exporting chunk387.mp3.
# Exporting chunk388.mp3.
# Exporting chunk389.mp3.
# Exporting chunk390.mp3.
# Exporting chunk391.mp3.
# Exporting chunk392.mp3.
# Exporting chunk393.mp3.
# Exporting chunk394.mp3.
# Exporting chunk395.mp3.
# Exporting chunk396.mp3.
# Exporting chunk397.mp3.
# Exporting chunk398.mp3.
# Exporting chunk399.mp3.
# Exporting chunk400.mp3.
# Exporting chunk401.mp3.
# Exporting chunk402.mp3.
# Exporting chunk403.mp3.
# Exporting chunk404.mp3.
# Exporting chunk405.mp3.
# Exporting chunk406.mp3.
# Exporting chunk407.mp3.
# Exporting chunk408.mp3.
# Exporting chunk409.mp3.
# Exporting chunk410.mp3.
# Exporting chunk411.mp3.
# Exporting chunk412.mp3.
# Exporting chunk413.mp3.
# Exporting chunk414.mp3.
# Exporting chunk415.mp3.
# Exporting chunk416.mp3.
# Exporting chunk417.mp3.
# Exporting chunk418.mp3.
# Exporting chunk419.mp3.
# Exporting chunk420.mp3.
# Exporting chunk421.mp3.
# Exporting chunk422.mp3.
# Exporting chunk423.mp3.
# Exporting chunk424.mp3.
# Exporting chunk425.mp3.
# Exporting chunk426.mp3.
# Exporting chunk427.mp3.
# Exporting chunk428.mp3.
# Exporting chunk429.mp3.
# Exporting chunk430.mp3.
# Exporting chunk431.mp3.
# Exporting chunk432.mp3.
# Exporting chunk433.mp3.
# Exporting chunk434.mp3.
# Exporting chunk435.mp3.
# Exporting chunk436.mp3.
# Exporting chunk437.mp3.
# Exporting chunk438.mp3.
# Exporting chunk439.mp3.
# Exporting chunk440.mp3.
# Exporting chunk441.mp3.
# Exporting chunk442.mp3.
# Exporting chunk443.mp3.
# Exporting chunk444.mp3.
# Exporting chunk445.mp3.
# Exporting chunk446.mp3.
# Exporting chunk447.mp3.
# Exporting chunk448.mp3.
# Exporting chunk449.mp3.
# Exporting chunk450.mp3.
# Exporting chunk451.mp3.
# Exporting chunk452.mp3.
# Exporting chunk453.mp3.
# Exporting chunk454.mp3.
# Exporting chunk455.mp3.
# Exporting chunk456.mp3.
# Exporting chunk457.mp3.
# Exporting chunk458.mp3.
# Exporting chunk459.mp3.
# Exporting chunk460.mp3.
# Exporting chunk461.mp3.
# Exporting chunk462.mp3.
# Exporting chunk463.mp3.
# Exporting chunk464.mp3.
# Exporting chunk465.mp3.
# Exporting chunk466.mp3.
# Exporting chunk467.mp3.
# Exporting chunk468.mp3.
# Exporting chunk469.mp3.
# Exporting chunk470.mp3.
# Exporting chunk471.mp3.
# Exporting chunk472.mp3.
# Exporting chunk473.mp3.
# Exporting chunk474.mp3.
# Exporting chunk475.mp3.
# Exporting chunk476.mp3.
# Exporting chunk477.mp3.
# Exporting chunk478.mp3.
# Exporting chunk479.mp3.
# Exporting chunk480.mp3.
# Exporting chunk481.mp3.
# Exporting chunk482.mp3.
# Exporting chunk483.mp3.
# Exporting chunk484.mp3.
# Exporting chunk485.mp3.
# Exporting chunk486.mp3.
# Exporting chunk487.mp3.
# Exporting chunk488.mp3.
# Exporting chunk489.mp3.
# Exporting chunk490.mp3.
# Exporting chunk491.mp3.
# Exporting chunk492.mp3.
# Exporting chunk493.mp3.
# Exporting chunk494.mp3.
# Exporting chunk495.mp3.
# Exporting chunk496.mp3.
# Exporting chunk497.mp3.
# Exporting chunk498.mp3.
# Exporting chunk499.mp3.
# Exporting chunk500.mp3.
# Exporting chunk501.mp3.
# Exporting chunk502.mp3.
# Exporting chunk503.mp3.
# Exporting chunk504.mp3.
# Exporting chunk505.mp3.
# Exporting chunk506.mp3.
# Exporting chunk507.mp3.
# Exporting chunk508.mp3.
# Exporting chunk509.mp3.
# Exporting chunk510.mp3.
# Exporting chunk511.mp3.
# Exporting chunk512.mp3.
# Exporting chunk513.mp3.
# Exporting chunk514.mp3.
# Exporting chunk515.mp3.
# Exporting chunk516.mp3.
# Exporting chunk517.mp3.
# Exporting chunk518.mp3.
# Exporting chunk519.mp3.
# Exporting chunk520.mp3.
# Exporting chunk521.mp3.
# Exporting chunk522.mp3.
# Exporting chunk523.mp3.
# Exporting chunk524.mp3.
# Exporting chunk525.mp3.
# Exporting chunk526.mp3.
# Exporting chunk527.mp3.
# Exporting chunk528.mp3.
# Exporting chunk529.mp3.
# Exporting chunk530.mp3.
# Exporting chunk531.mp3.
# Exporting chunk532.mp3.
# Exporting chunk533.mp3.
# Exporting chunk534.mp3.
# Exporting chunk535.mp3.
# Exporting chunk536.mp3.
# Exporting chunk537.mp3.
# Exporting chunk538.mp3.
# Exporting chunk539.mp3.
# Exporting chunk540.mp3.
# Exporting chunk541.mp3.
# Exporting chunk542.mp3.
# Exporting chunk543.mp3.
# Exporting chunk544.mp3.
# Exporting chunk545.mp3.
# Exporting chunk546.mp3.
# Exporting chunk547.mp3.
# Exporting chunk548.mp3.
# Exporting chunk549.mp3.
# Exporting chunk550.mp3.
# Exporting chunk551.mp3.
# Exporting chunk552.mp3.
# Exporting chunk553.mp3.
# Exporting chunk554.mp3.
# Exporting chunk555.mp3.
# Exporting chunk556.mp3.
# Exporting chunk557.mp3.
# Exporting chunk558.mp3.
# Exporting chunk559.mp3.
# Exporting chunk560.mp3.
# Exporting chunk561.mp3.
# Exporting chunk562.mp3.
# Exporting chunk563.mp3.
# Exporting chunk564.mp3.
# Exporting chunk565.mp3.
# Exporting chunk566.mp3.
# Exporting chunk567.mp3.
# Exporting chunk568.mp3.
# Exporting chunk569.mp3.
# Exporting chunk570.mp3.
# Exporting chunk571.mp3.
# Exporting chunk572.mp3.
# Exporting chunk573.mp3.
# Exporting chunk574.mp3.
# Exporting chunk575.mp3.
# Exporting chunk576.mp3.
# Exporting chunk577.mp3.
# Exporting chunk578.mp3.
# Exporting chunk579.mp3.
# Exporting chunk580.mp3.
# Exporting chunk581.mp3.
# Exporting chunk582.mp3.
# Exporting chunk583.mp3.
# Exporting chunk584.mp3.
# Exporting chunk585.mp3.
# Exporting chunk586.mp3.
# Exporting chunk587.mp3.
# Exporting chunk588.mp3.
# Exporting chunk589.mp3.
# Exporting chunk590.mp3.
# Exporting chunk591.mp3.
# Exporting chunk592.mp3.
# Exporting chunk593.mp3.
# Exporting chunk594.mp3.
# Exporting chunk595.mp3.
# Exporting chunk596.mp3.
# Exporting chunk597.mp3.
# Exporting chunk598.mp3.
# Exporting chunk599.mp3.
# Exporting chunk600.mp3.
# Exporting chunk601.mp3.
# Exporting chunk602.mp3.
# Exporting chunk603.mp3.
# Exporting chunk604.mp3.
# Exporting chunk605.mp3.
# Exporting chunk606.mp3.
# Exporting chunk607.mp3.
# Exporting chunk608.mp3.
# Exporting chunk609.mp3.
# Exporting chunk610.mp3.
# Exporting chunk611.mp3.
# Exporting chunk612.mp3.
# Exporting chunk613.mp3.
# Exporting chunk614.mp3.
# Exporting chunk615.mp3.
# Exporting chunk616.mp3.
# Exporting chunk617.mp3.
# Exporting chunk618.mp3.
# Exporting chunk619.mp3.
# Exporting chunk620.mp3.
# Exporting chunk621.mp3.
# Exporting chunk622.mp3.
# Exporting chunk623.mp3.
# Exporting chunk624.mp3.
# Exporting chunk625.mp3.
# Exporting chunk626.mp3.
# Exporting chunk627.mp3.
# Exporting chunk628.mp3.
# Exporting chunk629.mp3.
# Exporting chunk630.mp3.
# Exporting chunk631.mp3.
# Exporting chunk632.mp3.
# Exporting chunk633.mp3.
# Exporting chunk634.mp3.
# Exporting chunk635.mp3.
# Exporting chunk636.mp3.
# Exporting chunk637.mp3.
# Exporting chunk638.mp3.
# Exporting chunk639.mp3.
# Exporting chunk640.mp3.
# Exporting chunk641.mp3.
# Exporting chunk642.mp3.
# Exporting chunk643.mp3.
# Exporting chunk644.mp3.
# Exporting chunk645.mp3.
# Exporting chunk646.mp3.
# Exporting chunk647.mp3.
# Exporting chunk648.mp3.
# Exporting chunk649.mp3.
# Exporting chunk650.mp3.
# Exporting chunk651.mp3.
# Exporting chunk652.mp3.
# Exporting chunk653.mp3.
# Exporting chunk654.mp3.
# Exporting chunk655.mp3.
# Exporting chunk656.mp3.
# Exporting chunk657.mp3.
# Exporting chunk658.mp3.
# Exporting chunk659.mp3.
# Exporting chunk660.mp3.
# Exporting chunk661.mp3.
# Exporting chunk662.mp3.
# Exporting chunk663.mp3.
# Exporting chunk664.mp3.
# Exporting chunk665.mp3.
# Exporting chunk666.mp3.
# Exporting chunk667.mp3.
# Exporting chunk668.mp3.
# Exporting chunk669.mp3.
# Exporting chunk670.mp3.
# Exporting chunk671.mp3.
# Exporting chunk672.mp3.
# Exporting chunk673.mp3.
# Exporting chunk674.mp3.
# Exporting chunk675.mp3.
# Exporting chunk676.mp3.
# Exporting chunk677.mp3.
# Exporting chunk678.mp3.
# Exporting chunk679.mp3.
# Exporting chunk680.mp3.
# Exporting chunk681.mp3.
# Exporting chunk682.mp3.
# Exporting chunk683.mp3.
# Exporting chunk684.mp3.
# Exporting chunk685.mp3.
# Exporting chunk686.mp3.
# Exporting chunk687.mp3.
# Exporting chunk688.mp3.
# Exporting chunk689.mp3.
# Exporting chunk690.mp3.
# Exporting chunk691.mp3.
# Exporting chunk692.mp3.
# Exporting chunk693.mp3.
# Exporting chunk694.mp3.
# Exporting chunk695.mp3.
# Exporting chunk696.mp3.
# Exporting chunk697.mp3.
# Exporting chunk698.mp3.
# Exporting chunk699.mp3.
# Exporting chunk700.mp3.
# Exporting chunk701.mp3.
# Exporting chunk702.mp3.
# Exporting chunk703.mp3.
# Exporting chunk704.mp3.
# Exporting chunk705.mp3.
# Exporting chunk706.mp3.
# Exporting chunk707.mp3.
# Exporting chunk708.mp3.
# Exporting chunk709.mp3.
# Exporting chunk710.mp3.
# Exporting chunk711.mp3.
# Exporting chunk712.mp3.
# Exporting chunk713.mp3.
# Exporting chunk714.mp3.
# Exporting chunk715.mp3.
# Exporting chunk716.mp3.
# Exporting chunk717.mp3.
# Exporting chunk718.mp3.
# Exporting chunk719.mp3.
# Exporting chunk720.mp3.
# Exporting chunk721.mp3.
# Exporting chunk722.mp3.
# Exporting chunk723.mp3.
# Exporting chunk724.mp3.
# Exporting chunk725.mp3.
# Exporting chunk726.mp3.
# Exporting chunk727.mp3.
# Exporting chunk728.mp3.
# Exporting chunk729.mp3.
# Exporting chunk730.mp3.
# Exporting chunk731.mp3.
# Exporting chunk732.mp3.
# Exporting chunk733.mp3.
# Exporting chunk734.mp3.
# Exporting chunk735.mp3.
# Exporting chunk736.mp3.
# Exporting chunk737.mp3.
# Exporting chunk738.mp3.
# Exporting chunk739.mp3.
# Exporting chunk740.mp3.
# Exporting chunk741.mp3.
# Exporting chunk742.mp3.
# Exporting chunk743.mp3.
# Exporting chunk744.mp3.
# Exporting chunk745.mp3.
# Exporting chunk746.mp3.
# Exporting chunk747.mp3.
# Exporting chunk748.mp3.
# Exporting chunk749.mp3.
# Exporting chunk750.mp3.
# Exporting chunk751.mp3.
# Exporting chunk752.mp3.
# Exporting chunk753.mp3.
# Exporting chunk754.mp3.
# Exporting chunk755.mp3.
# Exporting chunk756.mp3.
# Exporting chunk757.mp3.
# Exporting chunk758.mp3.
# Exporting chunk759.mp3.
# Exporting chunk760.mp3.
# Exporting chunk761.mp3.
# Exporting chunk762.mp3.
# Exporting chunk763.mp3.
# Exporting chunk764.mp3.
# Exporting chunk765.mp3.
# Exporting chunk766.mp3.
# Exporting chunk767.mp3.
# Exporting chunk768.mp3.
# Exporting chunk769.mp3.
# Exporting chunk770.mp3.
# Exporting chunk771.mp3.
# Exporting chunk772.mp3.
# Exporting chunk773.mp3.
# Exporting chunk774.mp3.
# Exporting chunk775.mp3.
# Exporting chunk776.mp3.
# Exporting chunk777.mp3.
# Exporting chunk778.mp3.
# Exporting chunk779.mp3.
# Exporting chunk780.mp3.
# Exporting chunk781.mp3.
# Exporting chunk782.mp3.
# Exporting chunk783.mp3.
# Exporting chunk784.mp3.
# Exporting chunk785.mp3.
# Exporting chunk786.mp3.
# Exporting chunk787.mp3.
# Exporting chunk788.mp3.
# Exporting chunk789.mp3.
# Exporting chunk790.mp3.
# Exporting chunk791.mp3.
# Exporting chunk792.mp3.
# Exporting chunk793.mp3.
# Exporting chunk794.mp3.
# Exporting chunk795.mp3.
# Exporting chunk796.mp3.
# Exporting chunk797.mp3.
# Exporting chunk798.mp3.
# Exporting chunk799.mp3.
# Exporting chunk800.mp3.
# Exporting chunk801.mp3.
# Exporting chunk802.mp3.
# Exporting chunk803.mp3.

# %%
# remove chunks that have less than 3 second length

from pydub import AudioSegment
import os

def is_short_mp3(file_path):
    audio = AudioSegment.from_mp3(file_path)
    return len(audio) < 3000  # Duration in milliseconds (3 seconds)

# %%
# Example usage:
folder_path = "C:\\Users\\izard\\Documents\\GitHub\\malaysian-dialects-audio\\penang\\chunks"
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    if filename.lower().endswith(".mp3") and is_short_mp3(file_path):
        os.remove(file_path)
